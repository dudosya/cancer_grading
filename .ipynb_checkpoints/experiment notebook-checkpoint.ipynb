# %%
import dataset

# %%
folder_path = "./data/KBSMC_colon_tma_cancer_grading_512/tma_01"
data = dataset.RealCancerDataset(folder_path=folder_path)

# %%
data.__len__()
# Out:
# 1621

# %%
data.__getitem__(5)
# Out:
# (<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>, 2)
